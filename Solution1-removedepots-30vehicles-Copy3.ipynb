# %%
import plotly.offline as py
import plotly.graph_objs as go
import pandas as pd

py.offline.init_notebook_mode(connected=True)

#import data
df_ArrivalTimes = pd.read_excel("/Users/TomCreo/Desktop/Assignment - 30 vehicles, 3.0 wtm - Reopt 2_reformated_split2_wo depot.xlsx", 
                                sheet_name="ArrivalTimes")

df_Locations = pd.read_excel("/Users/TomCreo/Desktop/Assignment - 30 vehicles, 3.0 wtm - Reopt 2_reformated_split2_wo depot.xlsx", 
                             sheet_name="Locations")

df_ArrivalLoad = pd.read_excel("/Users/TomCreo/Desktop/Assignment - 30 vehicles, 3.0 wtm - Reopt 2_reformated_split2_wo depot.xlsx", 
                             sheet_name="ArrivalLoad")

df_Demand = pd.read_excel("/Users/TomCreo/Desktop/Assignment - 30 vehicles, 3.0 wtm - Reopt 2_reformated_split2_wo depot.xlsx", 
                             sheet_name="Demand")

df_Requests = pd.read_csv("/Users/TomCreo/Desktop/Google_Campus_Data_217_Shifted.csv")



#to store requestID associated with each stop
Veh0RequestID = []
Veh1RequestID = []
Veh2RequestID = []
Veh3RequestID = []
Veh4RequestID = []
Veh5RequestID = []
Veh6RequestID = []
Veh7RequestID = []
Veh8RequestID = []
Veh9RequestID = []
Veh10RequestID = []
Veh11RequestID = []
Veh12RequestID = []
Veh13RequestID = []
Veh14RequestID = []
Veh15RequestID = []
Veh16RequestID = []
Veh17RequestID = []
Veh18RequestID = []
Veh19RequestID = []
Veh20RequestID = []
Veh21RequestID = []
Veh22RequestID = []
Veh23RequestID = []
Veh24RequestID = []
Veh25RequestID = []
Veh26RequestID = []
Veh27RequestID = []
Veh28RequestID = []
Veh29RequestID = []

#to store latitude associated with each stop
Veh0Lat = []
Veh1Lat = []
Veh2Lat = []
Veh3Lat = []
Veh4Lat = []
Veh5Lat = []
Veh6Lat = []
Veh7Lat = []
Veh8Lat = []
Veh9Lat = []
Veh10Lat = []
Veh11Lat = []
Veh12Lat = []
Veh13Lat = []
Veh14Lat = []
Veh15Lat = []
Veh16Lat = []
Veh17Lat = []
Veh18Lat = []
Veh19Lat = []
Veh20Lat = []
Veh21Lat = []
Veh22Lat = []
Veh23Lat = []
Veh24Lat = []
Veh25Lat = []
Veh26Lat = []
Veh27Lat = []
Veh28Lat = []
Veh29Lat = []


#to store longitude associated with each stop
Veh0Long = []
Veh1Long = []
Veh2Long = []
Veh3Long = []
Veh4Long = []
Veh5Long = []
Veh6Long = []
Veh7Long = []
Veh8Long = []
Veh9Long = []
Veh10Long = []
Veh11Long = []
Veh12Long = []
Veh13Long = []
Veh14Long = []
Veh15Long = []
Veh16Long = []
Veh17Long = []
Veh18Long = []
Veh19Long = []
Veh20Long = []
Veh21Long = []
Veh22Long = []
Veh23Long = []
Veh24Long = []
Veh25Long = []
Veh26Long = []
Veh27Long = []
Veh28Long = []
Veh29Long = []


#marker fill based on pickup or dropoff
Veh0Fill = []
Veh1Fill = []
Veh2Fill = []
Veh3Fill = []
Veh4Fill = []
Veh5Fill = []
Veh6Fill = []
Veh7Fill = []
Veh8Fill = []
Veh9Fill = []
Veh10Fill = []
Veh11Fill = []
Veh12Fill = []
Veh13Fill = []
Veh14Fill = []
Veh15Fill = []
Veh16Fill = []
Veh17Fill = []
Veh18Fill = []
Veh19Fill = []
Veh20Fill = []
Veh21Fill = []
Veh22Fill = []
Veh23Fill = []
Veh24Fill = []
Veh25Fill = []
Veh26Fill = []
Veh27Fill = []
Veh28Fill = []
Veh29Fill = []
        
        

#calculate request ID associated with each stop
#extract latitude/longitude from requestID
#assign marker fill: pickup = 'circle', dropoff = 'circle-open'

for i, location in enumerate(df_Locations.Veh0.dropna(),start=1):
    veh0demand = df_Demand.Veh0.dropna()[i]
    if veh0demand == 1:
        Veh0RequestID.append(location/2)
        Veh0Lat.append(df_Requests.fromLatitude[location/2])
        Veh0Long.append(df_Requests.fromLongitude[location/2])
        Veh0Fill.append('circle')
    elif veh0demand == -1:
        Veh0RequestID.append((location-1)/2)
        Veh0Lat.append(df_Requests.toLatitude[(location-1)/2])
        Veh0Long.append(df_Requests.toLongitude[(location-1)/2])
        Veh0Fill.append('circle-open')

for i, location in enumerate(df_Locations.Veh1.dropna(),start=1):
    veh1demand = df_Demand.Veh1.dropna()[i]
    if veh1demand == 1:
        Veh1RequestID.append(location/2)
        Veh1Lat.append(df_Requests.fromLatitude[location/2])
        Veh1Long.append(df_Requests.fromLongitude[location/2])
        Veh1Fill.append('circle')
    elif veh1demand == -1:
        Veh1RequestID.append((location-1)/2)
        Veh1Lat.append(df_Requests.toLatitude[(location-1)/2])
        Veh1Long.append(df_Requests.toLongitude[(location-1)/2])
        Veh1Fill.append('circle-open')
        
for i, location in enumerate(df_Locations.Veh2.dropna(),start=1):
    veh2demand = df_Demand.Veh2.dropna()[i]
    if veh2demand == 1:
        Veh2RequestID.append(location/2)
        Veh2Lat.append(df_Requests.fromLatitude[location/2])
        Veh2Long.append(df_Requests.fromLongitude[location/2])
        Veh2Fill.append('circle')
    elif veh2demand == -1:
        Veh2RequestID.append((location-1)/2)
        Veh2Lat.append(df_Requests.toLatitude[(location-1)/2])
        Veh2Long.append(df_Requests.toLongitude[(location-1)/2])
        Veh2Fill.append('circle-open')
        
for i, location in enumerate(df_Locations.Veh3.dropna(),start=1):
    Veh3demand = df_Demand.Veh3.dropna()[i]
    if Veh3demand == 1:
        Veh3RequestID.append(location/2)
        Veh3Lat.append(df_Requests.fromLatitude[location/2])
        Veh3Long.append(df_Requests.fromLongitude[location/2])
        Veh3Fill.append('circle')
    elif Veh3demand == -1:
        Veh3RequestID.append((location-1)/2)
        Veh3Lat.append(df_Requests.toLatitude[(location-1)/2])
        Veh3Long.append(df_Requests.toLongitude[(location-1)/2])
        Veh3Fill.append('circle-open')
        
for i, location in enumerate(df_Locations.Veh4.dropna(),start=1):
    Veh4demand = df_Demand.Veh4.dropna()[i]
    if Veh4demand == 1:
        Veh4RequestID.append(location/2)
        Veh4Lat.append(df_Requests.fromLatitude[location/2])
        Veh4Long.append(df_Requests.fromLongitude[location/2])
        Veh4Fill.append('circle')
    elif Veh4demand == -1:
        Veh4RequestID.append((location-1)/2)
        Veh4Lat.append(df_Requests.toLatitude[(location-1)/2])
        Veh4Long.append(df_Requests.toLongitude[(location-1)/2])
        Veh4Fill.append('circle-open')
        
for i, location in enumerate(df_Locations.Veh5.dropna(),start=1):
    Veh5demand = df_Demand.Veh5.dropna()[i]
    if Veh5demand == 1:
        Veh5RequestID.append(location/2)
        Veh5Lat.append(df_Requests.fromLatitude[location/2])
        Veh5Long.append(df_Requests.fromLongitude[location/2])
        Veh5Fill.append('circle')
    elif Veh5demand == -1:
        Veh5RequestID.append((location-1)/2)
        Veh5Lat.append(df_Requests.toLatitude[(location-1)/2])
        Veh5Long.append(df_Requests.toLongitude[(location-1)/2])
        Veh5Fill.append('circle-open')

for i, location in enumerate(df_Locations.Veh6.dropna(),start=1):
    Veh6demand = df_Demand.Veh6.dropna()[i]
    if Veh6demand == 1:
        Veh6RequestID.append(location/2)
        Veh6Lat.append(df_Requests.fromLatitude[location/2])
        Veh6Long.append(df_Requests.fromLongitude[location/2])
        Veh6Fill.append('circle')
    elif Veh6demand == -1:
        Veh6RequestID.append((location-1)/2)
        Veh6Lat.append(df_Requests.toLatitude[(location-1)/2])
        Veh6Long.append(df_Requests.toLongitude[(location-1)/2])
        Veh6Fill.append('circle-open')
        
for i, location in enumerate(df_Locations.Veh7.dropna(),start=1):
    Veh7demand = df_Demand.Veh7.dropna()[i]
    if Veh7demand == 1:
        Veh7RequestID.append(location/2)
        Veh7Lat.append(df_Requests.fromLatitude[location/2])
        Veh7Long.append(df_Requests.fromLongitude[location/2])
        Veh7Fill.append('circle')
    elif Veh7demand == -1:
        Veh7RequestID.append((location-1)/2)
        Veh7Lat.append(df_Requests.toLatitude[(location-1)/2])
        Veh7Long.append(df_Requests.toLongitude[(location-1)/2])
        Veh7Fill.append('circle-open')
        
for i, location in enumerate(df_Locations.Veh8.dropna(),start=1):
    Veh8demand = df_Demand.Veh8.dropna()[i]
    if Veh8demand == 1:
        Veh8RequestID.append(location/2)
        Veh8Lat.append(df_Requests.fromLatitude[location/2])
        Veh8Long.append(df_Requests.fromLongitude[location/2])
        Veh8Fill.append('circle')
    elif Veh8demand == -1:
        Veh8RequestID.append((location-1)/2)
        Veh8Lat.append(df_Requests.toLatitude[(location-1)/2])
        Veh8Long.append(df_Requests.toLongitude[(location-1)/2])
        Veh8Fill.append('circle-open')
        
for i, location in enumerate(df_Locations.Veh9.dropna(),start=1):
    Veh9demand = df_Demand.Veh9.dropna()[i]
    if Veh9demand == 1:
        Veh9RequestID.append(location/2)
        Veh9Lat.append(df_Requests.fromLatitude[location/2])
        Veh9Long.append(df_Requests.fromLongitude[location/2])
        Veh9Fill.append('circle')
    elif Veh9demand == -1:
        Veh9RequestID.append((location-1)/2)
        Veh9Lat.append(df_Requests.toLatitude[(location-1)/2])
        Veh9Long.append(df_Requests.toLongitude[(location-1)/2])
        Veh9Fill.append('circle-open')
        
for i, location in enumerate(df_Locations.Veh10.dropna(),start=1):
    Veh10demand = df_Demand.Veh10.dropna()[i]
    if Veh10demand == 1:
        Veh10RequestID.append(location/2)
        Veh10Lat.append(df_Requests.fromLatitude[location/2])
        Veh10Long.append(df_Requests.fromLongitude[location/2])
        Veh10Fill.append('circle')
    elif Veh10demand == -1:
        Veh10RequestID.append((location-1)/2)
        Veh10Lat.append(df_Requests.toLatitude[(location-1)/2])
        Veh10Long.append(df_Requests.toLongitude[(location-1)/2])
        Veh10Fill.append('circle-open')

for i, location in enumerate(df_Locations.Veh11.dropna(),start=1):
    Veh11demand = df_Demand.Veh11.dropna()[i]
    if Veh11demand == 1:
        Veh11RequestID.append(location/2)
        Veh11Lat.append(df_Requests.fromLatitude[location/2])
        Veh11Long.append(df_Requests.fromLongitude[location/2])
        Veh11Fill.append('circle')
    elif Veh11demand == -1:
        Veh11RequestID.append((location-1)/2)
        Veh11Lat.append(df_Requests.toLatitude[(location-1)/2])
        Veh11Long.append(df_Requests.toLongitude[(location-1)/2])
        Veh11Fill.append('circle-open')
        
for i, location in enumerate(df_Locations.Veh12.dropna(),start=1):
    Veh12demand = df_Demand.Veh12.dropna()[i]
    if Veh12demand == 1:
        Veh12RequestID.append(location/2)
        Veh12Lat.append(df_Requests.fromLatitude[location/2])
        Veh12Long.append(df_Requests.fromLongitude[location/2])
        Veh12Fill.append('circle')
    elif Veh12demand == -1:
        Veh12RequestID.append((location-1)/2)
        Veh12Lat.append(df_Requests.toLatitude[(location-1)/2])
        Veh12Long.append(df_Requests.toLongitude[(location-1)/2])
        Veh12Fill.append('circle-open')
        
for i, location in enumerate(df_Locations.Veh13.dropna(),start=1):
    Veh13demand = df_Demand.Veh13.dropna()[i]
    if Veh13demand == 1:
        Veh13RequestID.append(location/2)
        Veh13Lat.append(df_Requests.fromLatitude[location/2])
        Veh13Long.append(df_Requests.fromLongitude[location/2])
        Veh13Fill.append('circle')
    elif Veh13demand == -1:
        Veh13RequestID.append((location-1)/2)
        Veh13Lat.append(df_Requests.toLatitude[(location-1)/2])
        Veh13Long.append(df_Requests.toLongitude[(location-1)/2])
        Veh13Fill.append('circle-open')
        
for i, location in enumerate(df_Locations.Veh14.dropna(),start=1):
    Veh14demand = df_Demand.Veh14.dropna()[i]
    if Veh14demand == 1:
        Veh14RequestID.append(location/2)
        Veh14Lat.append(df_Requests.fromLatitude[location/2])
        Veh14Long.append(df_Requests.fromLongitude[location/2])
        Veh14Fill.append('circle')
    elif Veh14demand == -1:
        Veh14RequestID.append((location-1)/2)
        Veh14Lat.append(df_Requests.toLatitude[(location-1)/2])
        Veh14Long.append(df_Requests.toLongitude[(location-1)/2])
        Veh14Fill.append('circle-open')
        
for i, location in enumerate(df_Locations.Veh15.dropna(),start=1):
    Veh15demand = df_Demand.Veh15.dropna()[i]
    if Veh15demand == 1:
        Veh15RequestID.append(location/2)
        Veh15Lat.append(df_Requests.fromLatitude[location/2])
        Veh15Long.append(df_Requests.fromLongitude[location/2])
        Veh15Fill.append('circle')
    elif Veh15demand == -1:
        Veh15RequestID.append((location-1)/2)
        Veh15Lat.append(df_Requests.toLatitude[(location-1)/2])
        Veh15Long.append(df_Requests.toLongitude[(location-1)/2])
        Veh15Fill.append('circle-open')
        
for i, location in enumerate(df_Locations.Veh16.dropna(),start=1):
    Veh16demand = df_Demand.Veh16.dropna()[i]
    if Veh16demand == 1:
        Veh16RequestID.append(location/2)
        Veh16Lat.append(df_Requests.fromLatitude[location/2])
        Veh16Long.append(df_Requests.fromLongitude[location/2])
        Veh16Fill.append('circle')
    elif Veh16demand == -1:
        Veh16RequestID.append((location-1)/2)
        Veh16Lat.append(df_Requests.toLatitude[(location-1)/2])
        Veh16Long.append(df_Requests.toLongitude[(location-1)/2])
        Veh16Fill.append('circle-open')
        
for i, location in enumerate(df_Locations.Veh17.dropna(),start=1):
    Veh17demand = df_Demand.Veh17.dropna()[i]
    if Veh17demand == 1:
        Veh17RequestID.append(location/2)
        Veh17Lat.append(df_Requests.fromLatitude[location/2])
        Veh17Long.append(df_Requests.fromLongitude[location/2])
        Veh17Fill.append('circle')
    elif Veh17demand == -1:
        Veh17RequestID.append((location-1)/2)
        Veh17Lat.append(df_Requests.toLatitude[(location-1)/2])
        Veh17Long.append(df_Requests.toLongitude[(location-1)/2])
        Veh17Fill.append('circle-open')
        
for i, location in enumerate(df_Locations.Veh18.dropna(),start=1):
    Veh18demand = df_Demand.Veh18.dropna()[i]
    if Veh18demand == 1:
        Veh18RequestID.append(location/2)
        Veh18Lat.append(df_Requests.fromLatitude[location/2])
        Veh18Long.append(df_Requests.fromLongitude[location/2])
        Veh18Fill.append('circle')
    elif Veh18demand == -1:
        Veh18RequestID.append((location-1)/2)
        Veh18Lat.append(df_Requests.toLatitude[(location-1)/2])
        Veh18Long.append(df_Requests.toLongitude[(location-1)/2])
        Veh18Fill.append('circle-open')
        
for i, location in enumerate(df_Locations.Veh19.dropna(),start=1):
    Veh19demand = df_Demand.Veh19.dropna()[i]
    if Veh19demand == 1:
        Veh19RequestID.append(location/2)
        Veh19Lat.append(df_Requests.fromLatitude[location/2])
        Veh19Long.append(df_Requests.fromLongitude[location/2])
        Veh19Fill.append('circle')
    elif Veh19demand == -1:
        Veh19RequestID.append((location-1)/2)
        Veh19Lat.append(df_Requests.toLatitude[(location-1)/2])
        Veh19Long.append(df_Requests.toLongitude[(location-1)/2])
        Veh19Fill.append('circle-open')
        
for i, location in enumerate(df_Locations.Veh20.dropna(),start=1):
    Veh20demand = df_Demand.Veh20.dropna()[i]
    if Veh20demand == 1:
        Veh20RequestID.append(location/2)
        Veh20Lat.append(df_Requests.fromLatitude[location/2])
        Veh20Long.append(df_Requests.fromLongitude[location/2])
        Veh20Fill.append('circle')
    elif Veh20demand == -1:
        Veh20RequestID.append((location-1)/2)
        Veh20Lat.append(df_Requests.toLatitude[(location-1)/2])
        Veh20Long.append(df_Requests.toLongitude[(location-1)/2])
        Veh20Fill.append('circle-open')
        
for i, location in enumerate(df_Locations.Veh21.dropna(),start=1):
    Veh21demand = df_Demand.Veh21.dropna()[i]
    if Veh21demand == 1:
        Veh21RequestID.append(location/2)
        Veh21Lat.append(df_Requests.fromLatitude[location/2])
        Veh21Long.append(df_Requests.fromLongitude[location/2])
        Veh21Fill.append('circle')
    elif Veh21demand == -1:
        Veh21RequestID.append((location-1)/2)
        Veh21Lat.append(df_Requests.toLatitude[(location-1)/2])
        Veh21Long.append(df_Requests.toLongitude[(location-1)/2])
        Veh21Fill.append('circle-open')
        
for i, location in enumerate(df_Locations.Veh22.dropna(),start=1):
    Veh22demand = df_Demand.Veh22.dropna()[i]
    if Veh22demand == 1:
        Veh22RequestID.append(location/2)
        Veh22Lat.append(df_Requests.fromLatitude[location/2])
        Veh22Long.append(df_Requests.fromLongitude[location/2])
        Veh22Fill.append('circle')
    elif Veh22demand == -1:
        Veh22RequestID.append((location-1)/2)
        Veh22Lat.append(df_Requests.toLatitude[(location-1)/2])
        Veh22Long.append(df_Requests.toLongitude[(location-1)/2])
        Veh22Fill.append('circle-open')
        
for i, location in enumerate(df_Locations.Veh23.dropna(),start=1):
    Veh23demand = df_Demand.Veh23.dropna()[i]
    if Veh23demand == 1:
        Veh23RequestID.append(location/2)
        Veh23Lat.append(df_Requests.fromLatitude[location/2])
        Veh23Long.append(df_Requests.fromLongitude[location/2])
        Veh23Fill.append('circle')
    elif Veh23demand == -1:
        Veh23RequestID.append((location-1)/2)
        Veh23Lat.append(df_Requests.toLatitude[(location-1)/2])
        Veh23Long.append(df_Requests.toLongitude[(location-1)/2])
        Veh23Fill.append('circle-open')
        
for i, location in enumerate(df_Locations.Veh24.dropna(),start=1):
    Veh24demand = df_Demand.Veh24.dropna()[i]
    if Veh24demand == 1:
        Veh24RequestID.append(location/2)
        Veh24Lat.append(df_Requests.fromLatitude[location/2])
        Veh24Long.append(df_Requests.fromLongitude[location/2])
        Veh24Fill.append('circle')
    elif Veh24demand == -1:
        Veh24RequestID.append((location-1)/2)
        Veh24Lat.append(df_Requests.toLatitude[(location-1)/2])
        Veh24Long.append(df_Requests.toLongitude[(location-1)/2])
        Veh24Fill.append('circle-open')
        
for i, location in enumerate(df_Locations.Veh25.dropna(),start=1):
    Veh25demand = df_Demand.Veh25.dropna()[i]
    if Veh25demand == 1:
        Veh25RequestID.append(location/2)
        Veh25Lat.append(df_Requests.fromLatitude[location/2])
        Veh25Long.append(df_Requests.fromLongitude[location/2])
        Veh25Fill.append('circle')
    elif Veh25demand == -1:
        Veh25RequestID.append((location-1)/2)
        Veh25Lat.append(df_Requests.toLatitude[(location-1)/2])
        Veh25Long.append(df_Requests.toLongitude[(location-1)/2])
        Veh25Fill.append('circle-open')
        
for i, location in enumerate(df_Locations.Veh26.dropna(),start=1):
    Veh26demand = df_Demand.Veh26.dropna()[i]
    if Veh26demand == 1:
        Veh26RequestID.append(location/2)
        Veh26Lat.append(df_Requests.fromLatitude[location/2])
        Veh26Long.append(df_Requests.fromLongitude[location/2])
        Veh26Fill.append('circle')
    elif Veh26demand == -1:
        Veh26RequestID.append((location-1)/2)
        Veh26Lat.append(df_Requests.toLatitude[(location-1)/2])
        Veh26Long.append(df_Requests.toLongitude[(location-1)/2])
        Veh26Fill.append('circle-open')

for i, location in enumerate(df_Locations.Veh27.dropna(),start=1):
    Veh27demand = df_Demand.Veh27.dropna()[i]
    if Veh27demand == 1:
        Veh27RequestID.append(location/2)
        Veh27Lat.append(df_Requests.fromLatitude[location/2])
        Veh27Long.append(df_Requests.fromLongitude[location/2])
        Veh27Fill.append('circle')
    elif Veh27demand == -1:
        Veh27RequestID.append((location-1)/2)
        Veh27Lat.append(df_Requests.toLatitude[(location-1)/2])
        Veh27Long.append(df_Requests.toLongitude[(location-1)/2])
        Veh27Fill.append('circle-open')
        
for i, location in enumerate(df_Locations.Veh28.dropna(),start=1):
    Veh28demand = df_Demand.Veh28.dropna()[i]
    if Veh28demand == 1:
        Veh28RequestID.append(location/2)
        Veh28Lat.append(df_Requests.fromLatitude[location/2])
        Veh28Long.append(df_Requests.fromLongitude[location/2])
        Veh28Fill.append('circle')
    elif Veh28demand == -1:
        Veh28RequestID.append((location-1)/2)
        Veh28Lat.append(df_Requests.toLatitude[(location-1)/2])
        Veh28Long.append(df_Requests.toLongitude[(location-1)/2])
        Veh28Fill.append('circle-open')
        
for i, location in enumerate(df_Locations.Veh29.dropna(),start=1):
    Veh29demand = df_Demand.Veh29.dropna()[i]
    if Veh29demand == 1:
        Veh29RequestID.append(location/2)
        Veh29Lat.append(df_Requests.fromLatitude[location/2])
        Veh29Long.append(df_Requests.fromLongitude[location/2])
        Veh29Fill.append('circle')
    elif Veh29demand == -1:
        Veh29RequestID.append((location-1)/2)
        Veh29Lat.append(df_Requests.toLatitude[(location-1)/2])
        Veh29Long.append(df_Requests.toLongitude[(location-1)/2])
        Veh29Fill.append('circle-open')

    
#define trace for vehicle
Vehicle0 = go.Scatter3d(
    x=Veh0Long,
    y=Veh0Lat,
    z=df_ArrivalTimes.Veh0.dropna(),
    name='Vehicle0',
    mode='lines+markers',
    marker=dict(
        size=6,
        symbol=Veh0Fill,
        line=dict(
            width=0.5
        ),
        opacity=0.7
    ),
    line=dict(),
    text=[""]
)

Vehicle1 = go.Scatter3d(
    x=Veh1Long,
    y=Veh1Lat,
    z=df_ArrivalTimes.Veh1.dropna(),
    name='Vehicle1',
    mode='lines+markers',
    marker=dict(
        size=6,
        symbol=Veh1Fill,
        line=dict(
            width=0.5
        ),
        opacity=0.7
    ),
    line=dict(),
    text=[""]
)

Vehicle2 = go.Scatter3d(
    x=Veh2Long,
    y=Veh2Lat,
    z=df_ArrivalTimes.Veh2.dropna(),
    name='Vehicle2',
    mode='lines+markers',
    marker=dict(
        size=6,
        symbol=Veh2Fill,
        line=dict(
            width=0.5
        ),
        opacity=0.7
    ),
    line=dict(
    ),
    text=[""]
)

Vehicle3 = go.Scatter3d(
    x=Veh3Long,
    y=Veh3Lat,
    z=df_ArrivalTimes.Veh3.dropna(),
    name='Vehicle3',
    mode='lines+markers',
    marker=dict(
        size=6,
        symbol=Veh3Fill,
        line=dict(
            width=0.5
        ),
        opacity=0.7
    ),
    line=dict(),
    text=[""]
)

Vehicle4 = go.Scatter3d(
    x=Veh4Long,
    y=Veh4Lat,
    z=df_ArrivalTimes.Veh4.dropna(),
    name='Vehicle4',
    mode='lines+markers',
    marker=dict(
        size=6,
        symbol=Veh4Fill,
        line=dict(
            width=0.5
        ),
        opacity=0.7
    ),
    line=dict(),
    text=[""]
)

Vehicle5 = go.Scatter3d(
    x=Veh5Long,
    y=Veh5Lat,
    z=df_ArrivalTimes.Veh5.dropna(),
    name='Vehicle5',
    mode='lines+markers',
    marker=dict(
        size=6,
        symbol=Veh5Fill,
        line=dict(
            width=0.5
        ),
        opacity=0.7
    ),
    line=dict(),
    text=[""]
)

Vehicle6 = go.Scatter3d(
    x=Veh6Long,
    y=Veh6Lat,
    z=df_ArrivalTimes.Veh6.dropna(),
    name='Vehicle6',
    mode='lines+markers',
    marker=dict(
        size=6,
        symbol=Veh6Fill,
        line=dict(
            width=0.5
        ),
        opacity=0.7
    ),
    line=dict(),
    text=[""]
)

Vehicle7 = go.Scatter3d(
    x=Veh7Long,
    y=Veh7Lat,
    z=df_ArrivalTimes.Veh7.dropna(),
    name='Vehicle7',
    mode='lines+markers',
    marker=dict(
        size=6,
        symbol=Veh7Fill,
        line=dict(
            width=0.5
        ),
        opacity=0.7
    ),
    line=dict( ),
    text=[""]
)

Vehicle8 = go.Scatter3d(
    x=Veh8Long,
    y=Veh8Lat,
    z=df_ArrivalTimes.Veh8.dropna(),
    name='Vehicle8',
    mode='lines+markers',
    marker=dict(
        size=6,
        symbol=Veh8Fill,
        line=dict(
            width=0.5
        ),
        opacity=0.7
    ),
    line=dict(),
    text=[""]
)

Vehicle9 = go.Scatter3d(
    x=Veh9Long,
    y=Veh9Lat,
    z=df_ArrivalTimes.Veh9.dropna(),
    name='Vehicle9',
    mode='lines+markers',
    marker=dict(
        size=6,
        symbol=Veh9Fill,
        line=dict(
            width=0.5
        ),
        opacity=0.7
    ),
    line=dict(),
    text=[""]
)

Vehicle10 = go.Scatter3d(
    x=Veh10Long,
    y=Veh10Lat,
    z=df_ArrivalTimes.Veh10.dropna(),
    name='Vehicle10',
    mode='lines+markers',
    marker=dict(
        size=6,
        symbol=Veh10Fill,
        line=dict(
            width=0.5
        ),
        opacity=0.7
    ),
    line=dict(),
    text=[""]
)

Vehicle11 = go.Scatter3d(
    x=Veh11Long,
    y=Veh11Lat,
    z=df_ArrivalTimes.Veh11.dropna(),
    name='Vehicle11',
    mode='lines+markers',
    marker=dict(
        size=6,
        symbol=Veh11Fill,
        line=dict(
            width=0.5
        ),
        opacity=0.7
    ),
    line=dict(),
    text=[""]
)

Vehicle12 = go.Scatter3d(
    x=Veh12Long,
    y=Veh12Lat,
    z=df_ArrivalTimes.Veh12.dropna(),
    name='Vehicle12',
    mode='lines+markers',
    marker=dict(
        size=6,
        symbol=Veh12Fill,
        line=dict(
            width=0.5
        ),
        opacity=0.7
    ),
    line=dict(),
    text=[""]
)

Vehicle13 = go.Scatter3d(
    x=Veh13Long,
    y=Veh13Lat,
    z=df_ArrivalTimes.Veh13.dropna(),
    name='Vehicle13',
    mode='lines+markers',
    marker=dict(
        size=6,
        symbol=Veh13Fill,
        line=dict(
            width=0.5
        ),
        opacity=0.7
    ),
    line=dict(),
    text=[""]
)

Vehicle14 = go.Scatter3d(
    x=Veh14Long,
    y=Veh14Lat,
    z=df_ArrivalTimes.Veh14.dropna(),
    name='Vehicle14',
    mode='lines+markers',
    marker=dict(
        size=6,
        symbol=Veh14Fill,
        line=dict(
            width=0.5
        ),
        opacity=0.7
    ),
    line=dict(),
    text=[""]
)

Vehicle15 = go.Scatter3d(
    x=Veh15Long,
    y=Veh15Lat,
    z=df_ArrivalTimes.Veh15.dropna(),
    name='Vehicle15',
    mode='lines+markers',
    marker=dict(
        size=6,
        symbol=Veh15Fill,
        line=dict(
            width=0.5
        ),
        opacity=0.7
    ),
    line=dict(),
    text=[""]
)

Vehicle16 = go.Scatter3d(
    x=Veh16Long,
    y=Veh16Lat,
    z=df_ArrivalTimes.Veh16.dropna(),
    name='Vehicle16',
    mode='lines+markers',
    marker=dict(
        size=6,
        symbol=Veh16Fill,
        line=dict(
            width=0.5
        ),
        opacity=0.7
    ),
    line=dict(),
    text=[""]
)

Vehicle17 = go.Scatter3d(
    x=Veh17Long,
    y=Veh17Lat,
    z=df_ArrivalTimes.Veh17.dropna(),
    name='Vehicle17',
    mode='lines+markers',
    marker=dict(
        size=6,
        symbol=Veh17Fill,
        line=dict(
            width=0.5
        ),
        opacity=0.7
    ),
    line=dict(),
    text=[""]
)

Vehicle18 = go.Scatter3d(
    x=Veh18Long,
    y=Veh18Lat,
    z=df_ArrivalTimes.Veh18.dropna(),
    name='Vehicle18',
    mode='lines+markers',
    marker=dict(
        size=6,
        symbol=Veh18Fill,
        line=dict(
            width=0.5),
        opacity=0.7
    ),
    line=dict(),
    text=[""]
)

Vehicle19 = go.Scatter3d(
    x=Veh19Long,
    y=Veh19Lat,
    z=df_ArrivalTimes.Veh19.dropna(),
    name='Vehicle19',
    mode='lines+markers',
    marker=dict(
        size=6,
        symbol=Veh19Fill,
        line=dict(
            width=0.5
        ),
        opacity=0.7
    ),
    line=dict(),
    text=[""]
)

Vehicle20 = go.Scatter3d(
    x=Veh20Long,
    y=Veh20Lat,
    z=df_ArrivalTimes.Veh20.dropna(),
    name='Vehicle20',
    mode='lines+markers',
    marker=dict(
        size=6,
        symbol=Veh20Fill,
        line=dict(
            width=0.5
        ),
        opacity=0.7
    ),
    line=dict(),
    text=[""]
)

Vehicle21 = go.Scatter3d(
    x=Veh21Long,
    y=Veh21Lat,
    z=df_ArrivalTimes.Veh21.dropna(),
    name='Vehicle21',
    mode='lines+markers',
    marker=dict(
        size=6,
        symbol=Veh21Fill,
        line=dict(
            width=0.5
        ),
        opacity=0.7
    ),
    line=dict(),
    text=[""]
)

Vehicle22 = go.Scatter3d(
    x=Veh22Long,
    y=Veh22Lat,
    z=df_ArrivalTimes.Veh22.dropna(),
    name='Vehicle22',
    mode='lines+markers',
    marker=dict(
        size=6,
        symbol=Veh22Fill,
        line=dict(
            width=0.5
        ),
        opacity=0.7
    ),
    line=dict(),
    text=[""]
)

Vehicle23 = go.Scatter3d(
    x=Veh23Long,
    y=Veh23Lat,
    z=df_ArrivalTimes.Veh23.dropna(),
    name='Vehicle23',
    mode='lines+markers',
    marker=dict(
        size=6,
        symbol=Veh23Fill,
        line=dict(
            width=0.5
        ),
        opacity=0.7
    ),
    line=dict(),
    text=[""]
)

Vehicle24 = go.Scatter3d(
    x=Veh24Long,
    y=Veh24Lat,
    z=df_ArrivalTimes.Veh24.dropna(),
    name='Vehicle24',
    mode='lines+markers',
    marker=dict(
        size=6,
        symbol=Veh24Fill,
        line=dict(
            width=0.5
        ),
        opacity=0.7
    ),
    line=dict(),
    text=[""]
)

Vehicle25 = go.Scatter3d(
    x=Veh25Long,
    y=Veh25Lat,
    z=df_ArrivalTimes.Veh25.dropna(),
    name='Vehicle25',
    mode='lines+markers',
    marker=dict(
        size=6,
        symbol=Veh25Fill,
        line=dict(
            width=0.5
        ),
        opacity=0.7
    ),
    line=dict(),
    text=[""]
)

Vehicle26 = go.Scatter3d(
    x=Veh26Long,
    y=Veh26Lat,
    z=df_ArrivalTimes.Veh26.dropna(),
    name='Vehicle26',
    mode='lines+markers',
    marker=dict(
        size=6,
        symbol=Veh26Fill,
        line=dict(
            width=0.5
        ),
        opacity=0.7
    ),
    line=dict(),
    text=[""]
)

Vehicle27 = go.Scatter3d(
    x=Veh27Long,
    y=Veh27Lat,
    z=df_ArrivalTimes.Veh27.dropna(),
    name='Vehicle27',
    mode='lines+markers',
    marker=dict(
        size=6,
        symbol=Veh27Fill,
        line=dict(
            width=0.5
        ),
        opacity=0.7
    ),
    line=dict(),
    text=[""]
)

Vehicle28 = go.Scatter3d(
    x=Veh28Long,
    y=Veh28Lat,
    z=df_ArrivalTimes.Veh28.dropna(),
    name='Vehicle28',
    mode='lines+markers',
    marker=dict(
        size=6,
        symbol=Veh28Fill,
        line=dict(
            width=0.5
        ),
        opacity=0.7
    ),
    line=dict(),
    text=[""]
)

Vehicle29 = go.Scatter3d(
    x=Veh29Long,
    y=Veh29Lat,
    z=df_ArrivalTimes.Veh29.dropna(),
    name='Vehicle29',
    mode='lines+markers',
    marker=dict(
        size=6,
        symbol=Veh29Fill,
        line=dict(
            width=0.5
        ),
        opacity=0.7
    ),
    line=dict(),
    text=[""]
)


data = [Vehicle0, Vehicle1, Vehicle2, Vehicle3, Vehicle4, 
        Vehicle5, Vehicle6, Vehicle7, Vehicle8, Vehicle9, 
        Vehicle10, Vehicle11, Vehicle12, Vehicle13, Vehicle14, 
        Vehicle15, Vehicle16, Vehicle17, Vehicle18, Vehicle19, 
        Vehicle20, Vehicle21, Vehicle22, Vehicle23, Vehicle24, 
        Vehicle25, Vehicle26, Vehicle27, Vehicle28, Vehicle29]

layout = go.Layout(
    margin=dict(
        l=0,
        r=0,
        b=0,
        t=0
    ),
    legend=dict(
        x=0,
        y=0,
        traceorder='normal',
        font=dict(
            family='sans-serif',
            size=12,
            color='#000'
        ),
        bgcolor='#E2E2E2',
        bordercolor='#FFFFFF',
        borderwidth=2
    )
)

fig = go.Figure(data=data, layout=layout)
py.offline.iplot(fig)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# ...
